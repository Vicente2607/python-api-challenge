# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# %%
# Import API key
from api_keys import weather_api_key
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"


# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# set up lists to hold reponse info
lat = []
lgn=[]
temp = []
Cloudiness=[]
Country=[]
Date=[]
Humidity=[]
Max_Temp=[]
Wind_Speed=[]
ciudad=[]
n=0
print("Inicio de Procesamiento de Datos")
print("--------------------------------")

for city in cities:
    response = requests.get(query_url + city).json()
    try:
        ciudad.append(response["name"])
        lat.append(response['coord']['lat'])
        lgn.append(response['coord']['lon'])
        Max_Temp.append(response['main']['temp_max'])
        Cloudiness.append(response['clouds']['all'])
        Humidity.append(response['main']['humidity'])
        Country.append(response["sys"]["country"])
        Date.append(response["dt"])
        Wind_Speed.append(response["wind"]["speed"])
        print("Processing Record "+str(n)+" "+response["name"])
        n=n+1
    except:
        pass
        print("City not found. Skipping...")
# Out:
# Inicio de Procesamiento de Datos
# --------------------------------
# Processing Record 0 Luderitz
# Processing Record 1 Butaritari
# Processing Record 2 Klaksvik
# City not found. Skipping...
# Processing Record 3 East London
# Processing Record 4 Punta Arenas
# Processing Record 5 Chapais
# Processing Record 6 Cambridge
# Processing Record 7 Juegang
# Processing Record 8 Albany
# City not found. Skipping...
# Processing Record 9 Carnarvon
# Processing Record 10 Highlands Ranch
# Processing Record 11 Dzhebariki-Khaya
# City not found. Skipping...
# Processing Record 12 Busselton
# Processing Record 13 Gornopravdinsk
# Processing Record 14 Rikitea
# Processing Record 15 Kaitangata
# Processing Record 16 Cervo
# Processing Record 17 Atuona
# Processing Record 18 Pirajui
# Processing Record 19 Nikolskoye
# Processing Record 20 Puerto Ayora
# Processing Record 21 Richards Bay
# Processing Record 22 Wladyslawowo
# Processing Record 23 Hithadhoo
# Processing Record 24 Broken Hill
# Processing Record 25 Mar del Plata
# City not found. Skipping...
# Processing Record 26 Cidreira
# Processing Record 27 Yellowknife
# Processing Record 28 Mount Gambier
# City not found. Skipping...
# Processing Record 29 Emerald
# Processing Record 30 Kruisfontein
# Processing Record 31 Hereford
# Processing Record 32 Hilo
# Processing Record 33 Kodiak
# Processing Record 34 Ponta do Sol
# City not found. Skipping...
# Processing Record 35 Port Hardy
# Processing Record 36 Cherskiy
# Processing Record 37 Castro
# Processing Record 38 Agua Blanca Sur
# Processing Record 39 Solnechnyy
# Processing Record 40 Kolondieba
# Processing Record 41 Chui
# Processing Record 42 Hong Kong
# Processing Record 43 Tiksi
# Processing Record 44 Xining
# Processing Record 45 Vestmannaeyjar
# Processing Record 46 Fairbanks
# Processing Record 47 Itacare
# Processing Record 48 Quatre Cocos
# Processing Record 49 Tygda
# Processing Record 50 Aklavik
# Processing Record 51 Yamada
# Processing Record 52 Ushuaia
# Processing Record 53 Saint Anthony
# Processing Record 54 Klyuchi
# Processing Record 55 Olafsvik
# City not found. Skipping...
# Processing Record 56 Pangai
# Processing Record 57 Kaliling
# Processing Record 58 Bredasdorp
# Processing Record 59 Cape Town
# Processing Record 60 Mersa Matruh
# City not found. Skipping...
# Processing Record 61 Chifeng
# Processing Record 518 Daragutan
# Processing Record 519 Xapuri
# Processing Record 520 The Valley
# Processing Record 521 Maxixe
# Processing Record 522 Beitbridge
# Processing Record 523 Redmond
# Processing Record 524 Raudeberg
# Processing Record 525 Chimoio
# Processing Record 526 Beringovskiy
# Processing Record 527 Fort Nelson
# Processing Record 528 Belle Fourche
# Processing Record 529 Santo Tomas
# Processing Record 530 Rio Grande
# Processing Record 531 Jinchang
# Processing Record 532 Fairmont
# City not found. Skipping...
# Processing Record 533 Buraidah
# Processing Record 534 Mayumba
# Processing Record 535 Swan Hill
# Processing Record 536 Uyemskiy
# Processing Record 537 Kavieng
# Processing Record 538 Aranjuez
# Processing Record 539 Enid
# Processing Record 540 Buritizeiro
# Processing Record 541 Mormugao
# Processing Record 542 Pointe Michel
# Processing Record 543 Nikolsk
# Processing Record 544 Inuvik
# Processing Record 545 Chumikan
# Processing Record 546 Haverfordwest
# Processing Record 547 Chicama
# Processing Record 548 Clyde River
# Processing Record 549 Impfondo
# Processing Record 550 Belaya Gora
# Processing Record 551 Dryden
# City not found. Skipping...
# Processing Record 552 Neuquen
# Processing Record 553 Kangaba
# Processing Record 554 Meulaboh
# Processing Record 555 Viedma
# City not found. Skipping...
# Processing Record 556 Agirish
# Processing Record 557 Noumea
# Processing Record 558 Ocean City
# Processing Record 559 Nortelandia
# Processing Record 560 Lodja
# Processing Record 561 Chalmette
# Processing Record 562 Narasannapeta
# Processing Record 563 Waingapu
# Processing Record 564 Leh
# Processing Record 565 Luancheng

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "City": ciudad,
    "Cloudiness":Cloudiness,
    "Country":Country,
    "Date":Date,
    "Humidity":Humidity,
    "lat": lat,
    "lon": lgn,
    "Max Temp": Max_Temp,
    "Wind Speed": Wind_Speed
}
weather_data = pd.DataFrame(weather_dict)

weather_data.to_csv(output_data_file)

weather_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    lat     lon  \
# 0      Luderitz           0      NA  1579881280        50 -26.65   15.16
# 1    Butaritari         100      KI  1579881263        76   3.07  172.79
# 2      Klaksvik         100      FO  1579881289        93  62.23   -6.59
# 3   East London          68      ZA  1579881261        78 -33.02   27.91
# 4  Punta Arenas          90      CL  1579881258        87 -53.15  -70.92
#
#    Max Temp  Wind Speed
# 0     26.00        6.20
# 1     28.77        3.97
# 2      3.00        4.60
# 3     24.00        6.70
# 4     10.00        5.10

# %%
fecha=Date[3]
fecha=pd.to_datetime(fecha,unit='s')

fecha
# Out:
# Timestamp('2020-01-24 15:54:21')

# %%
plt.scatter(weather_data["lat"],weather_data["Max Temp"], marker="o", facecolors="blue", edgecolors="black",
            s=50, alpha=0.25)
plt.title("Temperatura Máxima de Ciudad por Latitud  "+str(fecha))
plt.xlabel("Latitud")
plt.ylabel("Max Temp C")
plt.grid()
plt.savefig("Tempvslat.png")
print("Esta gráfica representa la temperatura máxima en relación a la latiud de la ciudad")
print("Se puede ver que hay algún tipo de relación")
# Out:
# Esta gráfica representa la temperatura máxima en relación a la latiud de la ciudad
# Se puede ver que hay algún tipo de relación

# %%
plt.scatter(weather_data["lat"],weather_data["Humidity"], marker="o", facecolors="red", edgecolors="black",
            s=50, alpha=0.25)
plt.title("Humedad de Ciudad por Latitud "+str(fecha))
plt.xlabel("Latitud")
plt.ylabel("% de Humedad")
plt.grid()
plt.savefig("humedadvslat.png")
print("Esta gráfica representa la el % de Humedad en relación a la latiud de la ciudad")
print("Se puede ver que hay una gran dispersión por lo que es dificíl que exista algún tipo de relación")
# Out:
# Esta gráfica representa la el % de Humedad en relación a la latiud de la ciudad
# Se puede ver que hay una gran dispersión por lo que es dificíl que exista algún tipo de relación

# %%
plt.scatter(weather_data["lat"],weather_data["Cloudiness"], marker="o", facecolors="green", edgecolors="black",
            s=50, alpha=0.25)
plt.title("Nubosidad de Ciudad por Latitud "+str(fecha))
plt.xlabel("Latitud")
plt.ylabel("% Nubosidad")
plt.grid()
plt.savefig("nubosidadvslat.png")
print("Esta gráfica representa la el % de Nubosidad en relación a la latiud de la ciudad")
print("Se puede ver que hay una gran dispersión por lo que es dificíl que exista algún tipo de relación")
# Out:
# Esta gráfica representa la el % de Nubosidad en relación a la latiud de la ciudad
# Se puede ver que hay una gran dispersión por lo que es dificíl que exista algún tipo de relación

# %%
plt.scatter(weather_data["lat"],weather_data["Wind Speed"], marker="o", facecolors="purple", edgecolors="black",
            s=50, alpha=0.25)
plt.title("Velocidad del viento de Ciudad por Latitud "+str(fecha))
plt.xlabel("Latitud")
plt.ylabel("Km/Hr")
plt.grid()
plt.savefig("vientovslat.png")
print("Esta gráfica representa la el % de Humedad en relación a la latiud de la ciudad")
print("Se puede ver que hay una gran dispersión por lo que es dificíl que exista algún tipo de relación")
# Out:
# Esta gráfica representa la el % de Humedad en relación a la latiud de la ciudad
# Se puede ver que hay una gran dispersión por lo que es dificíl que exista algún tipo de relación

# %%
# Separamos emisferio norte y emisferio sur
emisferio_norte =weather_data.loc[weather_data["lat"] > 0, :]
emisferio_sur=weather_data.loc[weather_data["lat"] <= 0, :]

# %%
# Hemisferio Norte regresion lineal de Temp vs Latitud
x_values = emisferio_norte["lat"]
y_values = emisferio_norte["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker="o", facecolors="blue", edgecolors="black",s=50, alpha=0.25)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,-40),fontsize=15,color="red")
plt.title("Temperatura Máxima de Ciudad por Latitud  "+str(fecha))
plt.xlabel("Latitud")
plt.ylabel("Max Temp C")
plt.show()
print("The r-squared is :"+str(rvalue))
print("Its look like there is a linear releation, the r is high and seems to be to mayor latitud the less temperture you has")
plt.savefig("norte_tempvslat.png")
# Out:
# The r-squared is :-0.8778051899397722
# Its look like there is a linear releation, the r is high and seems to be to mayor latitud the less temperture you has

# %%
# Hemisferio Sur regresion lineal de Temp vs Latitud
x_values = emisferio_sur["lat"]
y_values = emisferio_sur["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker="o", facecolors="blue", edgecolors="black",s=50, alpha=0.25)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,10),fontsize=15,color="red")
plt.title("Temperatura Máxima de Ciudad por Latitud  "+str(fecha))
plt.xlabel("Latitud")
plt.ylabel("Max Temp C")
plt.show()
print("The r-squared is :"+str(rvalue))
print("For this hemisfer the relation is quiet force, the r is below .5, so there is not a  relation ship ")
plt.savefig("sur_tempvslat.png")
# Out:
# The r-squared is :0.4964852688693036
# For this hemisfer the relation is quiet force, the r is below .5, so there is not a  relation ship

# %%
# Hemisferio Norte regresion lineal de Humedad vs Latitud
x_values = emisferio_norte["lat"]
y_values = emisferio_norte["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker="o", facecolors="red", edgecolors="black",s=50, alpha=0.25)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,10),fontsize=15,color="red")
plt.title("Humedad de Ciudad por Latitud   "+str(fecha))
plt.xlabel("Latitud")
plt.ylabel("% de Humedad")
plt.show()
print("The r-squared is :"+str(rvalue))
print("the value of r is less tha .5 so there is not a correlation between them")
plt.savefig("norte_humedad.png")
# Out:
# The r-squared is :0.39979298029674776
# the value of r is less tha .5 so there is not a correlation between them

# %%
# Hemisferio Sur regresion lineal de Humedad vs Latitud
x_values = emisferio_sur["lat"]
y_values = emisferio_sur["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker="o", facecolors="red", edgecolors="black",s=50, alpha=0.25)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,25),fontsize=15,color="red")
plt.title("Humedad de Ciudad por Latitud   "+str(fecha))
plt.xlabel("Latitud")
plt.ylabel("% de Humedad")
plt.show()
print("The r-squared is :"+str(rvalue))
print("the value of r is less tha .5 so there is not a correlation between them")
plt.savefig("sur_humedad.png")
# Out:
# The r-squared is :0.2494275562506647
# the value of r is less tha .5 so there is not a correlation between them

# %%
# Hemisferio Norte regresion lineal de nubosidad vs Latitud
x_values = emisferio_norte["lat"]
y_values = emisferio_norte["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker="o", facecolors="green", edgecolors="black",s=50, alpha=0.25)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,10),fontsize=15,color="red")
plt.title("Nubosidad de Ciudad por Latitud   "+str(fecha))
plt.xlabel("Latitud")
plt.ylabel("% Nubosidad")
plt.show()
print("The r-squared is :"+str(rvalue))
print("the value of r is less tha .5 so there is not a correlation between them")
plt.savefig("norte_nubosidad.png")
# Out:
# The r-squared is :0.25482303977876
# the value of r is less tha .5 so there is not a correlation between them

# %%
# Hemisferio Sur regresion lineal de nubosidad vs Latitud
x_values = emisferio_sur["lat"]
y_values = emisferio_sur["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker="o", facecolors="green", edgecolors="black",s=50, alpha=0.25)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
plt.title("Nubosidad de Ciudad por Latitud   "+str(fecha))
plt.xlabel("Latitud")
plt.ylabel("% Nubosidad")
plt.show()
print("The r-squared is :"+str(rvalue))
print("the value of r is less tha .5 so there is not a correlation between them")
plt.savefig("sur_nubosidad.png")
# Out:
# The r-squared is :0.13648021877965977
# the value of r is less tha .5 so there is not a correlation between them

# %%
# Hemisferio Norte regresion lineal de velocidad del viento vs Latitud
x_values = emisferio_norte["lat"]
y_values = emisferio_norte["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker="o", facecolors="purple", edgecolors="black",s=50, alpha=0.25)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,15),fontsize=15,color="red")
plt.title("Velocidad del viento de Ciudad por Latitud   "+str(fecha))
plt.xlabel("Latitud")
plt.ylabel("Km/Hr")
plt.show()
print("The r-squared is :"+str(rvalue))
print("the value of r is less tha .5 so there is not a correlation between them")
plt.savefig("norte_viento.png")
# Out:
# The r-squared is :0.06371475797565183
# the value of r is less tha .5 so there is not a correlation between them

# %%
# Hemisferio Sur regresion lineal de velocidad del viento vs Latitud
x_values = emisferio_sur["lat"]
y_values = emisferio_sur["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker="o", facecolors="purple", edgecolors="black",s=50, alpha=0.25)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,10),fontsize=15,color="red")
plt.title("Velocidad del viento de Ciudad por Latitud   "+str(fecha))
plt.xlabel("Latitud")
plt.ylabel("Km/Hr")
plt.show()
print("The r-squared is :"+str(rvalue))
print("the value of r is less tha .5 so there is not a correlation between them")
plt.savefig("sur_viento.png")
# Out:
# The r-squared is :-0.2956483823153577
# the value of r is less tha .5 so there is not a correlation between them
